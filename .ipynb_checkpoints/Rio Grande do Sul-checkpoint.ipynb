# %% [markdown]
# # Processamento de mapas

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
CIDADES = [
    "SANTA ROSA",
    "TRÊS PASSOS",
    "FREDERICO WESTPHALEN",
    "ERECHIM",
    "SANANDUVA",
    "CERRO LARGO",
    "SANTO ÂNGELO",
    "IJUÍ",
    "CARAZINHO",
    "PASSO FUNDO",
    "CRUZ ALTA",
    "NÃO-ME-TOQUE",
    "SOLEDADE"
]

# %%
SantaRosa = pd.read_excel("RS_A810_SANTA_ROSA_t_ur_rad_prec_2014_18.xlsx")
SantoAugusto = pd.read_excel("RS_A805_SANTO_AUGUSTO_t_ur_rad_prec_2014_18.xlsx")
CruzAlta = pd.read_excel("RS_A853_CRUZ_ALTA_t_ur_rad_prec_2014_18.xlsx")
SaoLuizGonzaga = pd.read_excel("RS_A852_SAO_LUIZ_GONZAGA_t_ur_rad_prec_2014_18.xlsx")

# %%
RS = gpd.read_file("rs_municipios/43MUE250GC_SIR.shp", encoding="utf-8")
RS_filtered = gpd.GeoDataFrame(RS[RS.NM_MUNICIP.isin(CIDADES)])
#RS_filtered.loc[370, ("Tar")] = SantaRosa[("tar")].min()
#RS_filtered.loc[380, ("Tar")] = SantoAugusto[("tar")].min()
#RS_filtered.loc[124, ("Tar")] = CruzAlta[("tar")].min()
#RS_filtered.loc[402, ("Tar")] = SaoLuizGonzaga[("tar")].min()
RS_filtered
# Out:
#                NM_MUNICIP CD_GEOCMU  \
# 89              CARAZINHO   4304705
# 101           CERRO LARGO   4305207
# 124             CRUZ ALTA   4306106
# 147               ERECHIM   4307005
# 172  FREDERICO WESTPHALEN   4308508
# 201                  IJUÍ   4310207
# 269          NÃO-ME-TOQUE   4312658
# 306           PASSO FUNDO   4314100
# 361             SANANDUVA   4316600
# 370            SANTA ROSA   4317202
# 375          SANTO ÂNGELO   4317509
# 438              SOLEDADE   4320800
# 462           TRÊS PASSOS   4321907
# 380                   NaN       NaN
# 402                   NaN       NaN
#
#                                               geometry   Tar
# 89   POLYGON ((-52.64216270234681 -28.1679056200482...   NaN
# 101  POLYGON ((-54.76611874438453 -28.0400920705925...   NaN
# 124  POLYGON ((-53.7030765569375 -28.48145347709624...  10.4
# 147  POLYGON ((-52.23707824926174 -27.4828265675919...   NaN
# 172  POLYGON ((-53.32110889915634 -27.2282169382610...   NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(16,16))
RS_filtered.plot(fc=[0.2,0.2,0.2], ax=ax)
#RS_filtered.plot(column="Tar", cmap="viridis", edgecolor='k', ax=ax)
