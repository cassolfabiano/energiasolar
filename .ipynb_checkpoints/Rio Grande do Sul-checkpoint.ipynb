# %% [markdown]
# # Processamento de mapas

# %%
import geopandas as gp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.cm import copper, viridis, plasma, Blues

# %%
CIDADES = [
    "SANTA ROSA",
    "TRÊS PASSOS",
    "FREDERICO WESTPHALEN",
    "ERECHIM",
    "SANANDUVA",
    "CERRO LARGO",
    "SANTO ÂNGELO",
    "IJUÍ",
    "CARAZINHO",
    "PASSO FUNDO",
    "CRUZ ALTA",
    "NÃO-ME-TOQUE",
    "SOLEDADE"
]

# %%
SaoLuizGonzaga = pd.read_excel("RS_A852_SAO_LUIZ_GONZAGA_t_ur_rad_prec_2014_18.xlsx")

# %%
" Média de irradiação para São Luiz Gonzaga: %.3f Watts" % SaoLuizGonzaga["rad"].mean()
# Out:
# ' Média de irradiação para São Luiz Gonzaga: 184.185 Watts'

# %% [markdown]
# - <b>Outono</b>: de 20 de março (13h15) a 21 de junho (7h07).
#
# - <b>Inverno</b>: de 21 de junho (7h07) a 22 de setembro (22h54).
#
# - <b>Primavera</b>: de 22 de setembro (22h54) a 21 de dezembro (19h23).
#
# - <b>Verão</b>: de 21 de dezembro (19h23) a 20 de março de 2019 (18h58).

# %%
SaoLuizGonzaga[SaoLuizGonzaga["mes"].isin([4,5,6])][SaoLuizGonzaga.columns[[1,19]]]
# Out:
#     mes  radmax
# 3     4   904.4
# 4     5   785.1
# 5     6   696.8
# 15    4   914.6
# 16    5   788.4
# 17    6   676.4
# 27    4   883.1
# 28    5   807.6
# 29    6   974.1
# 39    4   925.9
# 40    5   756.7
# 41    6   678.9
# 51    4   926.6
# 52    5   832.6
# 53    6   671.6

# %%
fig, ax = plt.subplots(figsize=(16,16))
url = "ftp://geoftp.ibge.gov.br/organizacao_do_territorio/malhas_territoriais/malhas_municipais/municipio_2014/RS/rs_municipios.zip"
rs = gp.read_file(url)
rs.plot(cmap=Blues, ax=ax)
